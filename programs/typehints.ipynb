# %%
# python is dynamically typed langauge
# you do not have to declare variable types before using them

x = 10
x = "hello"
x

# %%
# type hints are a way to gell python developers and tools what type of data is expected

# readability
# documentation
# stati checking


# this tells us :
# name should be string
# the function returns  a string

# %%
def greet(name: str) -> str:
    return "Hello" + name

# %%
print(greet("rita"))
# Out:
# Hellorita

# %%
# python provides builtin module called typing
# it contains tools for writing more advanced type hints

# Optional
# Union 
#List 
# Dict
# Tuple

# %%
from typing import List

numbers: List[int] = [10,20,30]
numbers
# Out:
# [10, 20, 30]

# %%
numbers = [10,20,30]
numbers
# Out:
# [10, 20, 30]

# %% [markdown]
# # floating points

# %%
price: float = 93.3

# %%
price = 934.3

# %% [markdown]
# ## strings

# %%
#name = "giri"

name: str = "giri"

# %% [markdown]
# ## booleans

# %%
#is_active = False

is_active = False

# %% [markdown]
# ## Lists

# %%
marks  = [10,20,30]

marks: list[int] = [30,40,40]

# %% [markdown]
# ## Dictionaries

# %%
#book = {"chap1":10 ,"chap2":20}
student: dict[str,int] = {"chap1":10 ,"chap2":20}
student
# Out:
# {'chap1': 10, 'chap2': 20}

# %%
## sets
#numbers = {10,10,10,20,20,30}

numbers :set[int] = {10,10,10,20,20}
numbers
# Out:
# {10, 20}

# %%
## type Hints for variables

username: str = "admin"
score :int = 343
temperature: float = 234.332

# %%
## Type Hints for functions
def square(num: int) -> int:
    return num * num 

square(10)
# Out:
# 100

# %%
from typing import Optional 

def get_user_name(user_id : int)  -> Optional[str]:
    if user_id == 1:
        return "giri"
    return None
